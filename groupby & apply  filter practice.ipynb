# %%
import pandas as pd

file = pd.read_csv('C:\\Users\\HP\\OneDrive\\Attachments\\Video_Games1.csv')
file
# Out:
#                                 Name Platform  Year_of_Release         Genre  \
# 0                         Wii Sports      Wii           2006.0        Sports
# 1                  Super Mario Bros.      NES           1985.0      Platform
# 2                     Mario Kart Wii      Wii           2008.0        Racing
# 3                  Wii Sports Resort      Wii           2009.0        Sports
# 4           Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing
# ...                              ...      ...              ...           ...
# 16714  Samurai Warriors: Sanada Maru      PS3           2016.0        Action
# 16715               LMA Manager 2007     X360           2006.0        Sports
# 16716        Haitaka no Psychedelica      PSV           2016.0     Adventure
# 16717               Spirits & Spells      GBA           2003.0      Platform
# 16718            Winning Post 8 2016      PSV           2016.0    Simulation
#
# ...

# %%
group_by = file.groupby('Genre')
group_by

# %%
for Genre, group in group_by:
    print(f"Genre: {Genre}")
    print(group)
# Out:
# Genre: Action
#                                     Name Platform  Year_of_Release   Genre  \
# 16                    Grand Theft Auto V      PS3           2013.0  Action
# 17         Grand Theft Auto: San Andreas      PS2           2004.0  Action
# 23                    Grand Theft Auto V     X360           2013.0  Action
# 24           Grand Theft Auto: Vice City      PS2           2002.0  Action
# 38                  Grand Theft Auto III      PS2           2001.0  Action
# ...                                  ...      ...              ...     ...
# 16696  Metal Gear Solid V: Ground Zeroes       PC           2014.0  Action
# 16698                     Carmageddon 64      N64           1999.0  Action
# 16699                    Planet Monsters      GBA           2001.0  Action
# 16703              The Longest 5 Minutes      PSV           2016.0  Action
# 16714      Samurai Warriors: Sanada Maru      PS3           2016.0  Action
#
# ...

# %%
file.dropna(inplace = True)

# %%
file.isnull().sum()
# Out:
# Name               0
# Platform           0
# Year_of_Release    0
# Genre              0
# Publisher          0
# NA_Sales           0
# EU_Sales           0
# JP_Sales           0
# Other_Sales        0
# Global_Sales       0
# Critic_Score       0
# Critic_Count       0
# User_Score         0
# User_Count         0
# Developer          0
# Rating             0
# dtype: int64

# %%
file.dtypes
# Out:
# Name                object
# Platform            object
# Year_of_Release    float64
# Genre               object
# Publisher           object
# NA_Sales           float64
# EU_Sales           float64
# JP_Sales           float64
# Other_Sales        float64
# Global_Sales       float64
# Critic_Score       float64
# Critic_Count       float64
# User_Score          object
# User_Count         float64
# Developer           object
# Rating              object
# dtype: object

# %%
file.head(5)
# Out:
#                     Name Platform  Year_of_Release     Genre Publisher  \
# 0             Wii Sports      Wii           2006.0    Sports  Nintendo
# 2         Mario Kart Wii      Wii           2008.0    Racing  Nintendo
# 3      Wii Sports Resort      Wii           2009.0    Sports  Nintendo
# 6  New Super Mario Bros.       DS           2006.0  Platform  Nintendo
# 7               Wii Play      Wii           2006.0      Misc  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales  Critic_Score  \
# 0     41.36     28.96      3.77         8.45         82.53          76.0
# 2     15.68     12.76      3.79         3.29         35.52          82.0
# 3     15.61     10.93      3.28         2.95         32.77          80.0
# 6     11.28      9.14      6.50         2.88         29.80          89.0
# 7     13.96      9.18      2.93         2.84         28.92          58.0
#
#    Critic_Count User_Score  User_Count Developer Rating
# ...

# %%
file['Total_sales'] = file.apply(lambda x : x['Other_Sales'] + x['Global_Sales'], axis = 1)
file
# Out:
#                                     Name Platform  Year_of_Release     Genre  \
# 0                             Wii Sports      Wii           2006.0    Sports
# 2                         Mario Kart Wii      Wii           2008.0    Racing
# 3                      Wii Sports Resort      Wii           2009.0    Sports
# 6                  New Super Mario Bros.       DS           2006.0  Platform
# 7                               Wii Play      Wii           2006.0      Misc
# ...                                  ...      ...              ...       ...
# 16667         E.T. The Extra-Terrestrial      GBA           2001.0    Action
# 16677     Mortal Kombat: Deadly Alliance      GBA           2002.0  Fighting
# 16696  Metal Gear Solid V: Ground Zeroes       PC           2014.0    Action
# 16700                             Breach       PC           2011.0   Shooter
# 16706            STORM: Frontline Nation       PC           2011.0  Strategy
#
# ...

# %%
# Find the total Global Sales for each Genre.
total = file.groupby('Genre')['Global_Sales'].sum()
total
# Out:
# Genre
# Action          1203.16
# Adventure         80.75
# Fighting         249.95
# Misc             416.26
# Platform         377.80
# Puzzle            78.90
# Racing           476.22
# Role-Playing     501.37
# Shooter          816.48
# Simulation       202.70
# Sports           833.85
# Strategy          69.61
# Name: Global_Sales, dtype: float64

# %%
#Find the average Critic Score for each Genre.
avg = file.groupby('Genre')['Critic_Score'].mean()
avg
# Out:
# Genre
# Action          67.828834
# Adventure       66.133065
# Fighting        69.732804
# Misc            67.460938
# Platform        70.000000
# Puzzle          70.694915
# Racing          69.543890
# Role-Playing    72.820225
# Shooter         70.981481
# Simulation      69.969697
# Sports          74.170732
# Strategy        73.123596
# Name: Critic_Score, dtype: float64

# %%
# Find the total number of games released per Publisher.
total_games = file.groupby('Publisher')['Name'].count()  #.sort_values(ascending = False)
total_games
# Out:
# Publisher
# 10TACLE Studios          1
# 1C Company               2
# 2D Boy                   1
# 3DO                     15
# 505 Games               80
#                         ..
# Zoo Games                3
# Zushi Games              1
# bitComposer Games        2
# id Software              1
# inXile Entertainment     1
# Name: Name, Length: 262, dtype: int64

# %%
#file['User_Score'] = file['User_Score'].astype('float64')
#file['User_Score'] = file['User_Score'].astype('int')
file.dtypes
# Out:
# Name                object
# Platform            object
# Year_of_Release    float64
# Genre               object
# Publisher           object
# NA_Sales           float64
# EU_Sales           float64
# JP_Sales           float64
# Other_Sales        float64
# Global_Sales       float64
# Critic_Score       float64
# Critic_Count       float64
# User_Score           int32
# User_Count         float64
# Developer           object
# Rating              object
# Total_sales        float64
# dtype: object

# %%
# Find the Genre with the highest average User Score.
avg_score = file.groupby('Genre')['User_Score'].mean()
avg_score
# Out:
# Genre
# Action          6.655215
# Adventure       6.713710
# Fighting        6.822751
# Misc            6.395833
# Platform        6.930521
# Puzzle          6.813559
# Racing          6.674699
# Role-Playing    7.168539
# Shooter         6.638889
# Simulation      6.760943
# Sports          6.646872
# Strategy        6.887640
# Name: User_Score, dtype: float64

# %%
#Find the Platform with the highest total Global Sales.
highest_sales = file.groupby('Platform')['Global_Sales'].max()
highest_sales
# Out:
# Platform
# 3DS     12.66
# DC       1.18
# DS      29.80
# GBA      6.41
# GC       7.07
# PC       8.01
# PS      10.95
# PS2     20.81
# PS3     21.04
# PS4     12.61
# PSP      7.69
# PSV      1.53
# Wii     82.53
# WiiU     7.09
# X360    21.81
# XB       8.49
# XOne     5.48
# Name: Global_Sales, dtype: float64

# %%
#Find the top 5 Publishers with the most games released.
top_five = file.groupby('Publisher')['Name'].count().sort_values(ascending = False).head(5)
top_five
# Out:
# Publisher
# Electronic Arts                944
# Ubisoft                        496
# Activision                     492
# Sony Computer Entertainment    316
# THQ                            307
# Name: Name, dtype: int64

# %%
#Find the year with the highest number of games released.
year = file.groupby('Year_of_Release')['Name'].count().sort_values(ascending = False).head(1)
year
# Out:
# Year_of_Release
# 2008.0    592
# Name: Name, dtype: int64

# %%
#Find the total North American Sales per Genre.

    #file['NA_Sales'] = file['NA_Sales'].astype(int)
total_na_sales = file.groupby('Genre')['NA_Sales'].sum()
total_na_sales
# Out:
# Genre
# Action          227
# Adventure         7
# Fighting         41
# Misc            118
# Platform         91
# Puzzle           11
# Racing          102
# Role-Playing     77
# Shooter         229
# Simulation       32
# Sports          199
# Strategy          5
# Name: NA_Sales, dtype: int32

# %%
# Create a function to classify games as "High Sales" if Global Sales > 1 million, else "Low Sales". Apply this function to create a new column.

file['Status'] = file['Global_Sales'].apply(lambda x : "high sales" if x > 10000000 else "Low Sales")
file
# Out:
#                                     Name Platform  Year_of_Release     Genre  \
# 0                             Wii Sports      Wii           2006.0    Sports
# 2                         Mario Kart Wii      Wii           2008.0    Racing
# 3                      Wii Sports Resort      Wii           2009.0    Sports
# 6                  New Super Mario Bros.       DS           2006.0  Platform
# 7                               Wii Play      Wii           2006.0      Misc
# ...                                  ...      ...              ...       ...
# 16667         E.T. The Extra-Terrestrial      GBA           2001.0    Action
# 16677     Mortal Kombat: Deadly Alliance      GBA           2002.0  Fighting
# 16696  Metal Gear Solid V: Ground Zeroes       PC           2014.0    Action
# 16700                             Breach       PC           2011.0   Shooter
# 16706            STORM: Frontline Nation       PC           2011.0  Strategy
#
# ...

# %%
# Create a function that calculates the total sales across all regions (NA, EU, JP, Other) and apply it to create a new column Total_Sales.def total_sales(row):
def total_sales(row):
    return row["NA_Sales"] + row["EU_Sales"] + row["JP_Sales"] + row["Other_Sales"]

file["Total_Sales"] = file.apply(total_sales, axis=1)
file
# Out:
#                                     Name Platform  Year_of_Release     Genre  \
# 0                             Wii Sports      Wii           2006.0    Sports
# 2                         Mario Kart Wii      Wii           2008.0    Racing
# 3                      Wii Sports Resort      Wii           2009.0    Sports
# 6                  New Super Mario Bros.       DS           2006.0  Platform
# 7                               Wii Play      Wii           2006.0      Misc
# ...                                  ...      ...              ...       ...
# 16667         E.T. The Extra-Terrestrial      GBA           2001.0    Action
# 16677     Mortal Kombat: Deadly Alliance      GBA           2002.0  Fighting
# 16696  Metal Gear Solid V: Ground Zeroes       PC           2014.0    Action
# 16700                             Breach       PC           2011.0   Shooter
# 16706            STORM: Frontline Nation       PC           2011.0  Strategy
#
# ...

# %%
# Find the longest game name in the dataset using the apply function.
#file['Game_Len'] = file['Name'].apply(len)
#file
file['Game_Len'].sort_values(ascending = False)
# Out:
# 9378     71
# 3985     66
# 2896     62
# 4483     62
# 8088     62
#          ..
# 14553     2
# 12163     2
# 6663      2
# 5968      2
# 3548      2
# Name: Game_Len, Length: 6825, dtype: int64

# %%
file.loc[file["Name"].apply(len).idxmax(), "Name"]
# Out:
# 'Shin Megami Tensei: Devil Summoner 2 - Raidou Kuzunoha vs. King Abaddon'

# %%
file.filter(like = '', axis = 0)
# Out:
# Empty DataFrame
# Columns: [Name, Platform, Year_of_Release, Genre, Publisher, NA_Sales, EU_Sales, JP_Sales, Other_Sales, Global_Sales, Critic_Score, Critic_Count, User_Score, User_Count, Developer, Rating, Total_sales, Status, Game_Len, Total_Sales]
# Index: []

# %% [markdown]
# #### filtering with one column

# %%
filtering = file[file['Critic_Score'] >= 90.0]
filtering
# Out:
#                                 Name Platform  Year_of_Release         Genre  \
# 11                     Mario Kart DS       DS           2005.0        Racing
# 16                Grand Theft Auto V      PS3           2013.0        Action
# 17     Grand Theft Auto: San Andreas      PS2           2004.0        Action
# 23                Grand Theft Auto V     X360           2013.0        Action
# 24       Grand Theft Auto: Vice City      PS2           2002.0        Action
# ...                              ...      ...              ...           ...
# 16122                       NBA 2K17       PC           2016.0        Sports
# 16193           Grand Theft Auto III       PC           2002.0        Action
# 16243                 IL-2 Sturmovik       PC           2001.0    Simulation
# 16355                        Deus Ex       PC           2000.0  Role-Playing
# 16380      Tiger Woods PGA Tour 2005       PC           2004.0        Sports
#
# ...

# %% [markdown]
# #### filtering with 2 columns

# %%
filtering = file[(file['Critic_Score'] >= 90.0) & (file['NA_Sales'] > 5)]
filtering
# Out:
#                               Name Platform  Year_of_Release     Genre  \
# 11                   Mario Kart DS       DS           2005.0    Racing
# 16              Grand Theft Auto V      PS3           2013.0    Action
# 17   Grand Theft Auto: San Andreas      PS2           2004.0    Action
# 23              Grand Theft Auto V     X360           2013.0    Action
# 24     Grand Theft Auto: Vice City      PS2           2002.0    Action
# 28          Gran Turismo 3: A-Spec      PS2           2001.0    Racing
# 36  Call of Duty: Modern Warfare 2     X360           2009.0   Shooter
# 38            Grand Theft Auto III      PS2           2001.0    Action
# 39         Super Smash Bros. Brawl      Wii           2008.0  Fighting
# 44                          Halo 3     X360           2007.0   Shooter
# 49              Super Mario Galaxy      Wii           2007.0  Platform
# 51             Grand Theft Auto IV     X360           2008.0    Action
# ...

# %% [markdown]
# #### filtering using query()

# %%
filter_query = file.query("Critic_Score > 90 and NA_Sales >= 5")
filter_query
# Out:
#                               Name Platform  Year_of_Release         Genre  \
# 11                   Mario Kart DS       DS           2005.0        Racing
# 16              Grand Theft Auto V      PS3           2013.0        Action
# 17   Grand Theft Auto: San Andreas      PS2           2004.0        Action
# 23              Grand Theft Auto V     X360           2013.0        Action
# 24     Grand Theft Auto: Vice City      PS2           2002.0        Action
# 28          Gran Turismo 3: A-Spec      PS2           2001.0        Racing
# 36  Call of Duty: Modern Warfare 2     X360           2009.0       Shooter
# 38            Grand Theft Auto III      PS2           2001.0        Action
# 39         Super Smash Bros. Brawl      Wii           2008.0      Fighting
# 44                          Halo 3     X360           2007.0       Shooter
# 49              Super Mario Galaxy      Wii           2007.0      Platform
# ...

# %% [markdown]
# #### filtering Rows Based on Values in a List

# %%
filtering_list = file[file['Game_Len'].isin([50,60,70])]
filtering_list
# Out:
#                                                     Name Platform  \
# 2816   Naruto Shippuden: Ultimate Ninja Storm Generat...      PS3
# 4390   Naruto Shippuden: Ultimate Ninja Storm Generat...     X360
# 5364   Tim Burton's The Nightmare Before Christmas: O...      PS2
# 6320   Fullmetal Alchemist 2: Curse of the Crimson El...      PS2
# 6572   Nancy Drew: The Mystery of the Clue Bender Soc...       DS
# 10926  Teenage Mutant Ninja Turtles: Mutants in Manha...      PS4
# 11215  Tim Burton's The Nightmare Before Christmas: O...       XB
# 11437  Adventure Time: The Secret of the Nameless Kin...      3DS
# 11853  The Lord of the Rings: The Battle for Middle-E...       PC
# 12477  Earth Defense Force 4.1: The Shadow of New Des...      PS4
# 12642  Adventure Time: The Secret of the Nameless Kin...     X360
# 13562  Teenage Mutant Ninja Turtles: Mutants in Manha...     XOne
# 15118  George of the Jungle and the Search for the Se...      Wii
#
# ...

# %% [markdown]
# #### Filtering Rows Based on String Matching

# %%
filtering_string = file[file['Genre'].str.contains('Racing')]
filtering_string
# Out:
#                            Name Platform  Year_of_Release   Genre  \
# 2                Mario Kart Wii      Wii           2008.0  Racing
# 11                Mario Kart DS       DS           2005.0  Racing
# 28       Gran Turismo 3: A-Spec      PS2           2001.0  Racing
# 40                 Mario Kart 7      3DS           2011.0  Racing
# 48               Gran Turismo 4      PS2           2004.0  Racing
# ...                         ...      ...              ...     ...
# 16513                    Ride 2       PC           2016.0  Racing
# 16553           Sega Rally Revo       PC           2007.0  Racing
# 16595         Micro Machines V4      PS2           2006.0  Racing
# 16631             Karnaaj Rally      GBA           2003.0  Racing
# 16634  Sébastien Loeb Rally Evo     XOne           2016.0  Racing
#
#                          Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# 2                         Nintendo        15     12.76      3.79         3.29
# ...

# %% [markdown]
# #### filtering missing values

# %%
null_values = file[file['Total_Sale'].isnull()]
null_values
# Out:
# Empty DataFrame
# Columns: [Name, Platform, Year_of_Release, Genre, Publisher, NA_Sales, EU_Sales, JP_Sales, Other_Sales, Global_Sales, Critic_Score, Critic_Count, User_Score, User_Count, Developer, Rating, Total_sales, Status, Game_Len, Total_Sales]
# Index: []

# %% [markdown]
# #### filtering with loc and iloc

# %%
file.loc[:,['Genre','Publisher']]
# Out:
#           Genre                     Publisher
# 0        Sports                      Nintendo
# 2        Racing                      Nintendo
# 3        Sports                      Nintendo
# 6      Platform                      Nintendo
# 7          Misc                      Nintendo
# ...         ...                           ...
# 16667    Action                      NewKidCo
# 16677  Fighting                  Midway Games
# 16696    Action  Konami Digital Entertainment
# 16700   Shooter                     Destineer
# 16706  Strategy                       Unknown
#
# [6825 rows x 2 columns]

# %%
file.iloc[:,[3,4]]
# Out:
#           Genre                     Publisher
# 0        Sports                      Nintendo
# 2        Racing                      Nintendo
# 3        Sports                      Nintendo
# 6      Platform                      Nintendo
# 7          Misc                      Nintendo
# ...         ...                           ...
# 16667    Action                      NewKidCo
# 16677  Fighting                  Midway Games
# 16696    Action  Konami Digital Entertainment
# 16700   Shooter                     Destineer
# 16706  Strategy                       Unknown
#
# [6825 rows x 2 columns]

# %%
file[file['Genre'] == 'Racing']
# Out:
#                            Name Platform  Year_of_Release   Genre  \
# 2                Mario Kart Wii      Wii           2008.0  Racing
# 11                Mario Kart DS       DS           2005.0  Racing
# 28       Gran Turismo 3: A-Spec      PS2           2001.0  Racing
# 40                 Mario Kart 7      3DS           2011.0  Racing
# 48               Gran Turismo 4      PS2           2004.0  Racing
# ...                         ...      ...              ...     ...
# 16513                    Ride 2       PC           2016.0  Racing
# 16553           Sega Rally Revo       PC           2007.0  Racing
# 16595         Micro Machines V4      PS2           2006.0  Racing
# 16631             Karnaaj Rally      GBA           2003.0  Racing
# 16634  Sébastien Loeb Rally Evo     XOne           2016.0  Racing
#
#                          Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# 2                         Nintendo        15     12.76      3.79         3.29
# ...

# %%
startswith = file[file['Name'].str.startswith('p')]
startswith
# Out:
#                            Name Platform  Year_of_Release   Genre  \
# 649   pro evolution soccer 2011      PS3           2010.0  Sports
# 2583  pro evolution soccer 2011      PSP           2010.0  Sports
# 3304  pro evolution soccer 2011     X360           2010.0  Sports
# 7150  pro evolution soccer 2011      Wii           2010.0  Sports
#
#                          Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# 649   Konami Digital Entertainment         0      1.17      0.54         0.41
# 2583  Konami Digital Entertainment         0      0.30      0.29         0.16
# 3304  Konami Digital Entertainment         0      0.44      0.00         0.07
# 7150  Konami Digital Entertainment         0      0.10      0.03         0.02
#
#       Global_Sales  Critic_Score  Critic_Count  User_Score  User_Count  \
# 649           2.41          77.0          40.0           6        85.0
# 2583          0.79          74.0          10.0           5         5.0
# ...
